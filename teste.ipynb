lib\site-packages (from tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (0.31.0)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.4 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (42.0.8)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (0.0.2)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (0.12.1)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (3.20.0)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (2.0.1)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr->-r requeriments.txt (line 5)) (1.0.0)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in c:\users\allan\flhe\.venv\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (0.9.4)
# Requirement already satisfied: ray==2.10.0 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr[simulation]->-r requeriments.txt (line 6)) (2.10.0)
# Requirement already satisfied: click>=7.0 in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (8.1.7)
# Requirement already satisfied: filelock in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (3.16.1)
# Requirement already satisfied: jsonschema in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (1.1.0)
# Requirement already satisfied: pyyaml in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (6.0.2)
# Requirement already satisfied: aiosignal in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (1.4.1)
# Requirement already satisfied: requests in c:\users\allan\flhe\.venv\lib\site-packages (from ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (2.32.3)
# Requirement already satisfied: datasets<2.20.0,>=2.14.6 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr-datasets->-r requeriments.txt (line 7)) (2.19.2)
# Requirement already satisfied: pyarrow==16.1.0 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr-datasets->-r requeriments.txt (line 7)) (16.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr-datasets->-r requeriments.txt (line 7)) (4.66.5)
# Requirement already satisfied: pillow>=6.2.1 in c:\users\allan\flhe\.venv\lib\site-packages (from flwr_datasets[vision]->-r requeriments.txt (line 8)) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\allan\flhe\.venv\lib\site-packages (from matplotlib->-r requeriments.txt (line 9)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\allan\flhe\.venv\lib\site-packages (from matplotlib->-r requeriments.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\allan\flhe\.venv\lib\site-packages (from matplotlib->-r requeriments.txt (line 9)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\allan\flhe\.venv\lib\site-packages (from matplotlib->-r requeriments.txt (line 9)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\allan\flhe\.venv\lib\site-packages (from matplotlib->-r requeriments.txt (line 9)) (3.1.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\allan\flhe\.venv\lib\site-packages (from cryptography<43.0.0,>=42.0.4->flwr->-r requeriments.txt (line 5)) (1.17.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\allan\flhe\.venv\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\allan\flhe\.venv\lib\site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (0.25.0)
# Requirement already satisfied: colorama in c:\users\allan\flhe\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->flwr-datasets->-r requeriments.txt (line 7)) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in c:\users\allan\flhe\.venv\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\users\allan\flhe\.venv\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (13.8.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\allan\flhe\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (0.44.0)
# Requirement already satisfied: pycparser in c:\users\allan\flhe\.venv\lib\site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr->-r requeriments.txt (line 5)) (2.22)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\allan\flhe\.venv\lib\site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (2.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\allan\flhe\.venv\lib\site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\allan\flhe\.venv\lib\site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\allan\flhe\.venv\lib\site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\allan\flhe\.venv\lib\site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets->-r requeriments.txt (line 7)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\allan\flhe\.venv\lib\site-packages (from requests->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\allan\flhe\.venv\lib\site-packages (from requests->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\allan\flhe\.venv\lib\site-packages (from requests->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\allan\flhe\.venv\lib\site-packages (from requests->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\allan\flhe\.venv\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\allan\flhe\.venv\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (2.18.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\allan\flhe\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\allan\flhe\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\allan\flhe\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\allan\flhe\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\allan\flhe\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (3.0.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\allan\flhe\.venv\lib\site-packages (from jsonschema->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\allan\flhe\.venv\lib\site-packages (from jsonschema->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\allan\flhe\.venv\lib\site-packages (from jsonschema->ray==2.10.0->flwr[simulation]->-r requeriments.txt (line 6)) (0.20.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\allan\flhe\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\allan\flhe\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\allan\flhe\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\allan\flhe\.venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\allan\flhe\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr->-r requeriments.txt (line 5)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\allan\flhe\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\allan\flhe\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\allan\flhe\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow->-r requeriments.txt (line 4)) (3.2.2)

# %%
import tenseal as ts
import os
import pickle
import numpy as np

# %%
context = ts.context(
    ts.SCHEME_TYPE.CKKS,   # Esquema CKKS para valores de ponto flutuante
    8192,                  # poly_modulus_degree = 4096
    None,                    # Um valor de padrão para a cadeia de módulos
    [40, 21, 21, 40]       # Coefficient modulus bits sizes (adequado para CKKS de 4096)
)

# %%
def context():
    """
    This function is used to create the context of the homomorphic encryption:
    it is used to create the keys and the parameters of the encryption scheme (CKKS).

    :return: the context of the homomorphic encryption
    """
    cont = ts.context(
        ts.SCHEME_TYPE.CKKS,
        poly_modulus_degree=8192,
        # This means that the coefficient modulus will contain 4 primes of 60 bits, 40 bits, 40 bits, and 60 bits.
        # coeff_mod_bit_sizes=[60, 40, 40, 60]
        coeff_mod_bit_sizes=[40, 21, 21, 40]
    )

    #cont.generate_galois_keys()  # You can create the Galois keys by calling generate_galois_keys
    cont.generate_relin_keys()
    cont.global_scale = 2 ** 30  # global_scale: the scaling factor, here set to 2**40 (same that pow(2, 40))
    return cont

# %%
def read_query(file_path):
    """
    This function is used to read a pickle file.

    :param file_path: the path of the file to read
    :return: the query and the context
    """
    if os.path.exists(file_path):
        with open(file_path, 'rb') as file:
            """
            # pickle.load(f)  # load to read file object

            file_str = f.read()
            client_query1 = pickle.loads(file_str)  # loads to read str class
            """
            query_str = pickle.load(file)

        contexte = query_str["context"]  # ts.context_from(query["contexte"])
        del query_str["context"]
        return query_str, contexte

    else:
        print("The file doesn't exist")

# %%
def combo_keys(client_path="secret.pkl", server_path="server_key.pkl"):
    """
    To create the public/private keys combination
    args:
        client_path: path to save the secret key (str)
        server_path: path to save the server public key (str)
    """
    context_client = context()
    write_query(f'context/{client_path}', {"context": context_client.serialize(save_secret_key=True)})
    write_query(f'context/{server_path}', {"context": context_client.serialize()})

    _, context_client = read_query(f'context/{client_path}')
    _, context_server = read_query(f'context/{server_path}')

    context_client = ts.context_from(context_client)
    context_server = ts.context_from(context_server)
    print("Is the client context private?", ("Yes" if context_client.is_private() else "No"))
    print("Is the server context private?", ("Yes" if context_server.is_private() else "No"))

# %%
def write_query(file_path, client_query):
    """
    This function is used to write a pickle file.

    :param file_path: the path of the file to write

    :param client_query: the query to write
    """
    with open(file_path, 'wb') as file:  # 'ab' to add existing file
        encode_str = pickle.dumps(client_query)
        file.write(encode_str)

# %%
combo_keys()
# Out:
# Is the client context private? Yes
# Is the server context private? No

# %%
with open('secret.pkl', 'rb') as file:
    secret = pickle.load(file)

context_client = ts.context_from(secret["context"])

# %%
with open('server_key.pkl', 'rb') as file:
    secret = pickle.load(file)

context_server = ts.context_from(secret["context"])

# %%
context_client.secret_key()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(10, 10, 1)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(64,  activation='relu'),
            tf.keras.layers.Dense(32,  activation='relu'),
            tf.keras.layers.Dense(10, activation='softmax'),

        ])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2024-09-21 18:55:57.864688: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-21 18:56:00.432440: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-21 18:56:00.442608: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-21 18:56:07.028596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-21 18:56:26.719215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-09-21 18:56:26.720674: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
flat_model = []
pesos      = model.get_weights()

for p in pesos:
    flat_model.extend(p.flatten())

# %%
he_layer = ts.ckks_tensor(context_client, [1, 2, 3, 4])

# %%
a = ts.ckks_tensor(context_client,[1/10])

he_layer *= a

# %%
a = he_layer.serialize()

# %%
new_he = ts.ckks_tensor_from(context_server, a)
new_he += 100
b = new_he.serialize()

# %%
resp = ts.ckks_tensor_from(context_client, b)
reshaped_model  = []
decrypted_model = resp.decrypt().raw

for p in pesos:
    reshaped_model.append(np.reshape(decrypted_model[:p.size], p.shape))
    decrypted_model = decrypted_model[p.size:]

# %%
model.set_weights(reshaped_model)

# %%
model.get_weights()
# Out:
# [array([[200.08612, 200.02266, 199.82983, 200.21436, 199.8971 , 200.01328,
#          200.12451, 199.82745, 199.90315, 200.05154],
#         [199.83098, 200.18414, 199.8082 , 199.78523, 200.21219, 200.23267,
#          200.20174, 199.81117, 200.05728, 200.2092 ],
#         [200.00955, 199.9493 , 199.80568, 200.13058, 199.82507, 199.97203,
#          199.972  , 200.15419, 200.04436, 200.09207],
#         [200.07076, 199.79007, 200.03278, 200.09113, 199.88052, 199.99623,
#          199.92026, 200.06418, 199.98376, 199.78018],
#         [199.80911, 199.84721, 199.77411, 200.09828, 199.79605, 199.97661,
#          199.88982, 199.86215, 200.07483, 200.04381],
#         [200.07211, 200.00148, 200.18217, 199.99603, 199.78609, 200.16315,
#          199.82014, 199.85194, 200.07477, 200.12158],
#         [199.80658, 200.14082, 199.85971, 200.14185, 199.85043, 200.04839,
#          200.19328, 200.017  , 199.7731 , 199.8791 ],
#         [200.06915, 200.12115, 199.82039, 200.0864 , 199.82788, 199.8415 ,
#          200.22272, 199.95064, 200.00882, 199.99419],
#         [200.03674, 200.22878, 200.12761, 200.23175, 200.187  , 200.2144 ,
#          199.78326, 200.19327, 199.82541, 200.09544],
#         [199.81345, 200.18182, 200.21892, 199.82196, 199.93193, 199.82205,
#          200.15735, 199.80579, 199.94713, 199.8493 ],
#         [199.76826, 200.1616 , 199.83698, 200.02339, 200.21645, 200.13063,
#          199.89671, 200.16475, 199.79375, 199.8695 ],
#         [200.09886, 200.18777, 200.16492, 200.06319, 200.09196, 200.08139,
#          200.17996, 199.96071, 200.07729, 199.91605],
#         [200.03389, 199.84013, 200.18489, 199.98236, 200.10173, 199.8398 ,
#          199.822  , 200.22789, 200.20541, 200.20682],
#         [199.99965, 199.77911, 200.14873, 199.94345, 199.89078, 200.13872,
#          199.87627, 199.9001 , 200.16101, 200.09514],
#         [200.11188, 199.97943, 199.85982, 200.08438, 199.99352, 199.89626,
#          200.09605, 200.1549 , 199.81578, 199.85452],
#         [200.12958, 200.1443 , 199.79071, 199.82562, 199.79126, 199.9162 ,
#          199.90213, 200.13664, 199.92807, 199.93361],
#         [200.00293, 200.1934 , 199.98767, 200.1069 , 199.97768, 200.22461,
#          199.95424, 199.94312, 199.94931, 200.06543],
#         [200.19794, 200.16595, 200.06194, 199.82634, 200.1085 , 199.95181,
#          200.07555, 200.14894, 200.20581, 200.0992 ],
#         [200.01839, 200.09128, 199.93793, 199.89536, 200.01506, 199.9777 ,
#          200.08409, 200.01768, 199.85107, 199.77591],
#         [199.83824, 200.13608, 200.09889, 199.88852, 199.88855, 199.99005,
#          200.21407, 199.91649, 199.84233, 200.08484],
#         [199.96603, 200.06369, 199.91684, 199.99658, 199.84259, 200.2102 ,
#          199.83534, 199.75836, 199.96829, 199.832  , 199.83426, 199.77344,
#          199.9128 , 200.25986, 199.83426, 199.9059 , 200.06842, 200.27158,
#          200.05139, 200.1412 , 200.22789, 199.90155, 199.93655, 199.9417 ,
#          199.859  , 199.92426, 200.16374, 200.13757, 199.87051, 200.1751 ,
#          200.20296, 199.82265, 200.23291, 199.76302, 200.2313 , 199.86008,
#          200.13904, 199.96964, 200.06657, 200.07674, 199.93138, 200.0011 ,
#          200.18668, 199.9911 , 199.91924, 200.26584]], dtype=float32),
#  array([200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200.],
#        dtype=float32),
#  array([[200.03075, 200.02412, 200.14839, ..., 199.99715, 200.01123,
#          199.86664],
#         [199.94443, 199.85536, 199.94186, ..., 200.04384, 200.0372 ,
#          200.12096],
#         [199.97089, 200.02896, 200.1822 , ..., 200.1031 , 199.75092,
#          199.81287],
#         ...,
#         [200.05028, 200.06993, 200.02415, ..., 200.1351 , 199.81905,
#          200.19229],
#         [200.20943, 199.88739, 199.88962, ..., 199.78027, 200.16049,
#          200.10963],
#         [200.1979 , 199.94371, 199.90723, ..., 199.98567, 200.14197,
#          199.9444 ]], dtype=float32),
#  array([200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200., 200.,
#         200., 200., 200., 200., 200., 200., 200., 200., 200., 200.],
#        dtype=float32),
#  array([[200.345  , 199.69197, 199.73465, 200.31471, 200.2445 , 200.07637,
#          200.28995, 199.62885, 199.82231, 200.2088 ],
#         [199.96182, 200.27989, 199.88412, 200.17078, 200.36472, 199.65317,
#          199.96217, 199.72334, 199.79222, 199.95955],
#         [200.31773, 199.81462, 200.13368, 200.35474, 199.66415, 199.91287,
#          200.05954, 199.83818, 199.992  , 200.17232],
#         [199.96344, 199.94124, 200.30171, 200.21281, 199.94684, 200.21416,
#          199.71149, 200.23346, 200.24493, 200.12505],
#         [200.13483, 200.16733, 200.13887, 199.83327, 199.65898, 200.22186,
#          199.9111 , 200.02855, 199.8555 , 200.299  ],
#         [200.20528, 199.93958, 199.82596, 200.13402, 200.16043, 200.30531,
#          200.32352, 199.84277, 200.07747, 199.72676],
#         [199.99745, 200.35385, 200.1663 , 199.65225, 199.81284, 199.79012,
#          200.25903, 199.74937, 200.13889, 200.13335],
#         [199.6866 , 199.72731, 199.6681 , 199.70357, 199.95016, 200.33342,
#          200.11781, 200.10938, 200.29326, 199.75258],
#         [199.81032, 199.81194, 199.73007, 200.23433, 199.90913, 199.64047,
#          199.73212, 200.23045, 199.97618, 199.96667],
#         [200.15576, 200.12709, 199.9816 , 200.07423, 199.95444, 200.29373,
